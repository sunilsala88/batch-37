# %%
data='hello world'
f1=open('demo1.txt','w')
f1.write(data)
f1.close()

# %%
d1=open(r'/Users/algo trading 2026/batch 37/7_file_exception/demo1.txt','r')
d=d1.read()
print(d)
d1.close()
# Out:
# this is demo1 data
