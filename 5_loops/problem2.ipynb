# %%
i=1
while True:
    if i>100:
        break
    if i<50 or i>60:
        print(i)
    i=i+1

# %%
stock_prices={'amzn':500,'msft':200,'goog':1000,'tsla':300,'nifty':600}
portfolio={}
while True:
    name=input('enter stock name(type q to quit):')
    
    if name=='q':
        break
    if name=='msft':
        print('msft is not available try some other stock')
        continue
    price=stock_prices.get(name)
    print(name,price)
    # if price is not None:
    if price :
        portfolio.update({name:price})
    else:
        print('stock not found')
print('portfolio:',portfolio)
# Out:
# amzn 500
# goog 1000
# msft is not available try some other stock
# tsla 300
# portfolio: {'amzn': 500, 'goog': 1000, 'tsla': 300}

# %%
num=''
# True->boolean value
# 0->interger Value
# Truthy value->
if 10:
    print('inside if')
else:
    print('inside else')
#truthy and falsy value
#falsy ->0,False,'',[],{},None
# Out:
# inside else

# %%
l1=[44,55,66,77,88]
#[88,77,66,55,44]
