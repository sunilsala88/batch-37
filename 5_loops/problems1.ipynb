# %%
number=3
for i in range(1,11):
    # print(number,'*',i,'=',number*i)
    print(f"{number} * {i} = {number*i}")
# Out:
# 3 * 1 = 3
# 3 * 2 = 6
# 3 * 3 = 9
# 3 * 4 = 12
# 3 * 5 = 15
# 3 * 6 = 18
# 3 * 7 = 21
# 3 * 8 = 24
# 3 * 9 = 27
# 3 * 10 = 30

# %%
number=5
fact=1
for i in range(1,number+1):
    fact=fact*i
print(fact)
# Out:
# 120
