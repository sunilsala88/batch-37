# %%
from  ib_async import *
util.startLoop()



ib = IB()
ib.connect('127.0.0.1', 7497, clientId=13)
# Out:
# <IB connected to 127.0.0.1:7497 clientId=13>
# Error 10089, reqId 4: Requested market data requires additional subscription for API. See link in 'Market Data Connections' dialog for more details.AAPL NASDAQ.NMS/TOP/ALL, contract: Stock(conId=265598, symbol='AAPL', exchange='SMART', primaryExchange='NASDAQ', currency='USD', localSymbol='AAPL', tradingClass='NMS')
# Error 10089, reqId 5: Requested market data requires additional subscription for API. See link in 'Market Data Connections' dialog for more details.AAPL NASDAQ.NMS/TOP/ALL, contract: Stock(conId=265598, symbol='AAPL', exchange='SMART', primaryExchange='NASDAQ', currency='USD', localSymbol='AAPL', tradingClass='NMS')
# ...

# %%
c1=Crypto('BTC', 'PAXOS', 'USD')
c1 = ib.qualifyContracts(c1)[0]
c1
# Out:
# Crypto(conId=479624278, symbol='BTC', exchange='PAXOS', currency='USD', localSymbol='BTC.USD', tradingClass='BTC')

# %%
t=ib.reqTickers(c1)[0]
t
# Out:
# Ticker(contract=Crypto(conId=479624278, symbol='BTC', exchange='PAXOS', currency='USD', localSymbol='BTC.USD', tradingClass='BTC'), time=datetime.datetime(2026, 7, 26, 12, 16, 29, 286414, tzinfo=datetime.timezone.utc), timestamp=1785068189.286437, minTick=0.25, bid=64560.0, bidSize=0.06195786, ask=64560.25, askSize=0.06501095, last=64560.25, lastSize=2.96e-06, lastTimestamp=datetime.datetime(2026, 7, 26, 12, 16, 28, tzinfo=datetime.timezone.utc), volume=86.0, high=64606.25, low=62000.0, close=64164.0, halted=0, defaults=IBDefaults(emptyPrice=-1, emptySize=0, unset=nan, timezone=datetime.timezone.utc), created=True)

# %%
t
# Out:
# Ticker(contract=Crypto(conId=479624278, symbol='BTC', exchange='PAXOS', currency='USD', localSymbol='BTC.USD', tradingClass='BTC'), time=datetime.datetime(2026, 7, 26, 12, 16, 29, 286414, tzinfo=datetime.timezone.utc), timestamp=1785068189.286437, minTick=0.25, bid=64560.0, bidSize=0.06195786, ask=64560.25, askSize=0.06501095, last=64560.25, lastSize=2.96e-06, lastTimestamp=datetime.datetime(2026, 7, 26, 12, 16, 28, tzinfo=datetime.timezone.utc), volume=86.0, high=64606.25, low=62000.0, close=64164.0, halted=0, defaults=IBDefaults(emptyPrice=-1, emptySize=0, unset=nan, timezone=datetime.timezone.utc), created=True)

# %%
                              defaults=IBDefaults(emptyPrice=-1, emptySize=0, unset=nan, timezone=datetime.timezone.utc), created=True)Ticker(contract=Crypto(conId=479624278, symbol='BTC', exchange='PAXOS', currency='USD', localSymbol='BTC.USD', tradingClass='BTC'), 
       time=datetime.datetime(2026, 7, 26, 12, 16, 29, 286414, 
                              tzinfo=datetime.timezone.utc), 
                              timestamp=1785068189.286437, 
                              minTick=0.25, 
                              bid=64560.0, 
                              bidSize=0.06195786, 
                              ask=64560.25, 
                              askSize=0.06501095, 
                              last=64560.25, 
                              lastSize=2.96e-06, 
                              lastTimestamp=datetime.datetime(2026, 7, 26, 12, 16, 28, tzinfo=datetime.timezone.utc), 
                              volume=86.0, 
                              high=64606.25, 
                              low=62000.0, 
                              close=64164.0, 
                              halted=0,
# Out:
# Ticker(contract=Stock(conId=265598, symbol='AAPL', exchange='SMART', primaryExchange='NASDAQ', currency='USD', localSymbol='AAPL', tradingClass='NMS'), minTick=0.01, bboExchange='9c0001', defaults=IBDefaults(emptyPrice=-1, emptySize=0, unset=nan, timezone=datetime.timezone.utc), created=True)
