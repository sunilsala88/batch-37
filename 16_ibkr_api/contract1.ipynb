# %%
from  ib_async import *
util.startLoop()



ib = IB()
ib.connect('127.0.0.1', 7497, clientId=11)
# Out:
# <IB connected to 127.0.0.1:7497 clientId=11>
# Error 200, reqId 3: No security definition has been found for the request, contract: Stock(symbol='TSLA1', exchange='SMART', currency='USD')

# %%
s1=Stock('GOOG','SMART','USD')
s1
ib.qualifyContracts(s1)
# Out:
# [Stock(conId=208813720, symbol='GOOG', exchange='SMART', primaryExchange='NASDAQ', currency='USD', localSymbol='GOOG', tradingClass='NMS')]
