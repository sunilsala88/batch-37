# %%
from  ib_async import *
util.startLoop()



ib = IB()
ib.connect('127.0.0.1', 7497, clientId=11)
# Out:
# <IB connected to 127.0.0.1:7497 clientId=11>
# Error 200, reqId 4: No security definition has been found for the request, contract: Stock(symbol='RELIANCE', exchange='BSE', currency='INR')
# Error 200, reqId 7: No security definition has been found for the request, contract: Forex('USDUSD', exchange='IDEALPRO')

# %%
s1=Stock('RELIANCE','NSE','INR')
s1
ib.qualifyContracts(s1)
# Out:
# [Stock(conId=44652000, symbol='RELIANCE', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='RELIANCE', tradingClass='RELIANCE')]

# %%
S3=Contract(secType='STK',symbol='ONGC',exchange='NSE',currency='INR')
ib.qualifyContracts(S3)
# Out:
# [Contract(secType='STK', conId=83845926, symbol='ONGC', exchange='NSE', primaryExchange='NSE', currency='INR', localSymbol='ONGC', tradingClass='ONGC')]

# %%
# f1=Forex(symbol='EUR', exchange='IDEALPRO', currency='USD')
f1=Forex('EURUSD')
ib.qualifyContracts(f1)
# Out:
# [Forex('EURUSD', conId=12087792, exchange='IDEALPRO', localSymbol='EUR.USD', tradingClass='EUR.USD')]

# %%
cf1=Contract(secType='CASH',symbol='EUR',exchange='IDEALPRO',currency='USD')
ib.qualifyContracts(cf1)
# Out:
# [Contract(secType='CASH', conId=12087792, symbol='EUR', exchange='IDEALPRO', currency='USD', localSymbol='EUR.USD', tradingClass='EUR.USD')]

# %%
c1=Crypto('BTC','PAXOS','USD')
ib.qualifyContracts(c1)
# Out:
# [Crypto(conId=479624278, symbol='BTC', exchange='PAXOS', currency='USD', localSymbol='BTC.USD', tradingClass='BTC')]

# %%
cc1=Contract(secType='CRYPTO',symbol='BTC',exchange='PAXOS',currency='USD')
ib.qualifyContracts(cc1)
# Out:
# [Contract(secType='CRYPTO', conId=479624278, symbol='BTC', exchange='PAXOS', currency='USD', localSymbol='BTC.USD', tradingClass='BTC')]

# %%
fut1=Future("ES", "20260918", "CME")
ib.qualifyContracts(fut1)
# Out:
# [Future(conId=649180671, symbol='ES', lastTradeDateOrContractMonth='20260918', multiplier='50', exchange='CME', currency='USD', localSymbol='ESU6', tradingClass='ES')]

# %%
fut1=Future("NIFTY50", "20260728", "NSE",currency='INR')
ib.qualifyContracts(fut1)
# Out:
# [Future(conId=878163674, symbol='NIFTY50', lastTradeDateOrContractMonth='20260728', multiplier='1', exchange='NSE', currency='INR', localSymbol='NIFTY26JULFUT', tradingClass='NIFTY')]

# %%
o1=Option("SPX", "20260720", 7500, "C", "SMART")
ib.qualifyContracts(o1)
# Out:
# [Option(conId=891287777, symbol='SPX', lastTradeDateOrContractMonth='20260720', strike=7500.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='SPXW  260720C07500000', tradingClass='SPXW')]

# %%
cc1=Contract(secType='OPT',symbol='SPX',exchange='SMART',currency='USD',lastTradeDateOrContractMonth='20260720',strike=7500,right='C')
ib.qualifyContracts(cc1)
# Out:
# [Contract(secType='OPT', conId=891287777, symbol='SPX', lastTradeDateOrContractMonth='20260720', strike=7500.0, right='C', multiplier='100', exchange='SMART', currency='USD', localSymbol='SPXW  260720C07500000', tradingClass='SPXW')]
