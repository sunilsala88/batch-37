# %%
import pandas as pd
df=pd.read_csv('/Users/algo trading 2026/batch 37/11_pandas/unicorn.csv')
df
# Out:
#           Company  Valuation Date Joined                         Industry  \
# 0       Bytedance        180  07-04-2017          Artificial intelligence
# 1          SpaceX        100  01-12-2012                            Other
# 2           SHEIN        100  03-07-2018  E-commerce & direct-to-consumer
# 3          Stripe         95  23-01-2014                          Fintech
# 4          Klarna         46  12-12-2011                          Fintech
# ...           ...        ...         ...                              ...
# 1069     Zhaogang          1  29-06-2017  E-commerce & direct-to-consumer
# 1070  Zhuan Zhuan          1  18-04-2017  E-commerce & direct-to-consumer
# 1071     Zihaiguo          1  06-05-2021                Consumer & retail
# 1072         Zopa          1  19-10-2021                          Fintech
# 1073        Zwift          1  16-09-2020  E-commerce & direct-to-consumer
#
#                City         Country      Continent  Year Founded  Funding
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1074 entries, 0 to 1073
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Company       1074 non-null   str
#  1   Valuation     1074 non-null   int64
#  2   Date Joined   1074 non-null   datetime64[us]
#  3   Industry      1074 non-null   str
#  4   City          1058 non-null   str
#  5   Country       1074 non-null   str
#  6   Continent     1074 non-null   str
#  7   Year Founded  1074 non-null   int64
#  8   Funding       1073 non-null   float64
# dtypes: datetime64[us](1), float64(1), int64(2), str(5)
# memory usage: 75.6 KB

# %%
df['Date Joined']=pd.to_datetime(df['Date Joined'],format='%d-%m-%Y')
df
# Out:
#           Company  Valuation Date Joined                         Industry  \
# 0       Bytedance        180  2017-04-07          Artificial intelligence
# 1          SpaceX        100  2012-12-01                            Other
# 2           SHEIN        100  2018-07-03  E-commerce & direct-to-consumer
# 3          Stripe         95  2014-01-23                          Fintech
# 4          Klarna         46  2011-12-12                          Fintech
# ...           ...        ...         ...                              ...
# 1069     Zhaogang          1  2017-06-29  E-commerce & direct-to-consumer
# 1070  Zhuan Zhuan          1  2017-04-18  E-commerce & direct-to-consumer
# 1071     Zihaiguo          1  2021-05-06                Consumer & retail
# 1072         Zopa          1  2021-10-19                          Fintech
# 1073        Zwift          1  2020-09-16  E-commerce & direct-to-consumer
#
#                City         Country      Continent  Year Founded  Funding
# ...

# %%
start=pd.to_datetime('2022-01-01')
end=pd.to_datetime('2025-12-31')
start,end
# Out:
# (Timestamp('2022-01-01 00:00:00'), Timestamp('2025-12-31 00:00:00'))

# %%
df[(df['Date Joined']<end) & (df['Date Joined']>start)]
# Out:
#                      Company  Valuation Date Joined  \
# 18                      Miro         18  2022-01-05
# 117          RELEX Solutions          6  2022-02-17
# 163                    Qonto          5  2022-01-11
# 210   Globalization Partners          4  2022-01-24
# 220               Hozon Auto          4  2022-02-22
# ...                      ...        ...         ...
# 1017                 Scandit          1  2022-02-09
# 1037         Tarana Wireless          1  2022-03-23
# 1045               Timescale          1  2022-02-22
# 1053                    Veev          1  2022-02-24
# 1059               Watershed          1  2022-02-08
#
#                                  Industry           City        Country  \
# 18           Internet software & services  San Francisco  United States
# 117   Supply chain, logistics, & delivery       Helsinki        Finland
# 163                               Fintech          Paris         France
# ...
